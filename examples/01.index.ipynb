# %% [markdown]
# # ipycanvas Examples Gallery
#
# Welcome to the ipycanvas demo index. This notebook is the entry point for exploring the examples in this folder.
#
# 1. Run the next cell to launch Conway's Game of Life.
# 2. Use Start, Stop, Step, and Randomize to explore different evolutions.
# 3. Tune speed, cell size, density, and colors live.
# 4. Browse the catalog below to jump to focused demos.

# %%
from game_of_life import game_of_life_demo
game_of_life_demo()

# %% [markdown]
# ## How To Use This Gallery
#
# - Start with the categories that match your goal (animation, performance, interaction, plotting, etc.).
# - Open any notebook link below in JupyterLab/Notebook and run all cells.
# - If you are performance-tuning, compare `08.animation.ipynb`, `07.batch_drawing.ipynb`, and `16.offscreen_canvas.ipynb`.

# %% [markdown]
# ## Notebook Catalog
#
# ### 1) Start Here: Core Drawing
#
# 1. [02.polygon.ipynb](02.polygon.ipynb) - Draw and stroke polygons, including generated regular polygons.
# 2. [03.gradients.ipynb](03.gradients.ipynb) - Use linear and radial gradients with ipycanvas color stops.
# 3. [04.patterns.ipynb](04.patterns.ipynb) - Fill shapes with repeating image or canvas-based patterns.
# 4. [05.sprites.ipynb](05.sprites.ipynb) - Render sprites from images, arrays, and cached canvases efficiently.
# 5. [06.binary_image.ipynb](06.binary_image.ipynb) - Push NumPy image buffers directly with `put_image_data`.
# 6. [07.batch_drawing.ipynb](07.batch_drawing.ipynb) - Draw large batches of rects/circles with vectorized APIs.
#
# ### 2) Animation And Interaction
#
# 1. [08.animation.ipynb](08.animation.ipynb) - Compare animation loops and learn why `hold_canvas` and `canvas.sleep` matter.
# 2. [09.interaction_during_animation.ipynb](09.interaction_during_animation.ipynb) - Keep animations interactive while updating particles live.
# 3. [10.particle_system.ipynb](10.particle_system.ipynb) - Build colorful and moving particle simulations.
# 4. [11.drag_and_drop_example.ipynb](11.drag_and_drop_example.ipynb) - Implement draggable shapes with mouse events.
# 5. [12.hand_drawing.ipynb](12.hand_drawing.ipynb) - Freehand drawing with rough-style rendering and UI controls.
# 6. [13.clock.ipynb](13.clock.ipynb) - Interactive analog clock with widget-controlled hour and minute hands.
# 7. [14.conways_game_of_life.ipynb](14.conways_game_of_life.ipynb) - Conway simulation rendered on canvas.
#
# ### 3) Layers, Performance, And Rendering Modes
#
# 1. [15.multicanvas.ipynb](15.multicanvas.ipynb) - Compose multiple stacked layers with independent redraw frequency.
# 2. [16.offscreen_canvas.ipynb](16.offscreen_canvas.ipynb) - Explore compatibility/offscreen rendering for smoother loops.
#
# ### 4) Plotting, Mapping, And 3D-Style Demos
#
# 1. [17.plotting.ipynb](17.plotting.ipynb) - A custom Python plotting mini-library with draggable marks.
# 2. [18.plot3d.ipynb](18.plot3d.ipynb) - Lightweight local 3D plotting utilities rendered on canvas.
# 3. [19.3d_monkey.ipynb](19.3d_monkey.ipynb) - NumPy-powered mesh rendering from OBJ-style triangle data.
# 4. [20.mapping.ipynb](20.mapping.ipynb) - Map-style interaction with events, timing, and layered rendering.
#
# ### 5) Generative And Stylized Art
#
# 1. [21.fractals_tree.ipynb](21.fractals_tree.ipynb) - Recursive branching fractal tree generation.
# 2. [22.fractals_forest.ipynb](22.fractals_forest.ipynb) - Multi-tree fractal forest with random variation.
# 3. [23.roughcanvas.ipynb](23.roughcanvas.ipynb) - Hand-drawn visual style using `RoughCanvas`.
